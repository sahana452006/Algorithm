# %% [markdown]
# <a href="https://colab.research.google.com/github/sahana452006/Algorithm/blob/main/dfs_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt


g = {
    '5': ['3', '7'],
    '3': ['2', '4'],
    '7': ['8'],
    '2': [],
    '4': ['8'],
    '8': []
}


G = nx.Graph()
for node in g:
    for neighbor in g[node]:
        G.add_edge(node, neighbor)


plt.figure(figsize=(5, 5))
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray', node_size=2000, font_size=15)
plt.show()

def dfs(visited, g, node):
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for neighbour in g[node]:
            dfs(visited, g, neighbour)


print("Following is the Depth-First Search:")
visited = set()
dfs(visited, g, '5')
# Out:
# Following is the Depth-First Search:
# 5 3 2 4 8 7
